# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import random
import pickle
import time

from rdkit import Chem
from rdkit.Chem import Draw


fp_radius = 2
fp_bits = 4096

import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
from Transformer.Transformer import Transformer, create_look_ahead_mask, create_padding_mask, create_masks, CustomSchedule, evaluate, loss_function, BeamSearch 
from ChemUtils.PreProcessing import read_file, smiles_to_fp_array, CHAR_LEN, array_to_smiles

# %% [markdown]
# # Smiles and FP encoding

# %%
smiles_array, fp_array = read_file("Data/train.csv", useCount=True, fp_bits=fp_bits)

# %% [markdown]
# # Split train and test set

# %%
'''
train_rate = 0.98

r = np.random.uniform(size=[smiles_array.shape[0]])
r = r<0.98

train_smiles = smiles_array[r]
train_fp = fp_array[r]

test_smiles = smiles_array[~r]
test_fp = fp_array[~r]

with open("Data/train_dupli_count.pkl", "wb") as pf:
    pickle.dump([train_smiles,train_fp], pf)
    
with open("Data/test_dupli_count.pkl", "wb") as pf:
    pickle.dump([test_smiles,test_fp], pf)
'''
# Out:
# '\ntrain_rate = 0.98\n\nr = np.random.uniform(size=[smiles_array.shape[0]])\nr = r<0.98\n\ntrain_smiles = smiles_array[r]\ntrain_fp = fp_array[r]\n\ntest_smiles = smiles_array[~r]\ntest_fp = fp_array[~r]\n\nwith open("Data/train_dupli_count.pkl", "wb") as pf:\n    pickle.dump([train_smiles,train_fp], pf)\n    \nwith open("Data/test_dupli_count.pkl", "wb") as pf:\n    pickle.dump([test_smiles,test_fp], pf)\n'

# %% [markdown]
# # Define training data generator

# %%
#with open("Data/train_dupli_count.pkl",  'rb') as pf:
    #trains = pickle.load(pf)

BATCH_SIZE = 200

gen = tf.data.Dataset.from_tensor_slices((smiles_array, fp_array))
gen = gen.shuffle(buffer_size=smiles_array.shape[0])
gen = gen.batch(BATCH_SIZE)

AUTOTUNE = tf.data.experimental.AUTOTUNE
gen = gen.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Define transformer model

# %%
num_layers = 6
d_model = 256
num_heads = 8
dff = 2048
input_vocab_size=fp_bits+3
target_vocab_size = CHAR_LEN+3
pe_input = fp_array.shape[1]
pe_target= smiles_array.shape[1]
rate = 0.1
EPOCHS=35

transformer = Transformer(num_layers, d_model, num_heads, dff, 
                    input_vocab_size, target_vocab_size,
                    pe_input, pe_target, rate)

# %%
#transformer.load_weights("Models/FPsToSmiles")

# %% [markdown]
# # Metrics

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(
    name='train_accuracy')

# %% [markdown]
# # Training

# %%
learning_rate = CustomSchedule(d_model)
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                     epsilon=1e-9)

# %%
checkpoint_path = "./checkpoints/FPsToSMILES(DupliCount)/train"

ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# restore
if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print ('Latest checkpoint restored!!')
# Out:
# Latest checkpoint restored!!

# %%
train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int32),
    tf.TensorSpec(shape=(None, None), dtype=tf.int32),
]

@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]
    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(inp, tar_inp)

    with tf.GradientTape() as tape:
        predictions, _ = transformer(inp, tar_inp, 
                                     True, 
                                     enc_padding_mask, 
                                     combined_mask, 
                                     dec_padding_mask)
        loss = loss_function(tar_real, predictions)

    gradients = tape.gradient(loss, transformer.trainable_variables)    
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

    train_loss(loss)
    train_accuracy(tar_real, predictions)

# %%
for epoch in range(EPOCHS):
    start = time.time()

    train_loss.reset_states()
    train_accuracy.reset_states()

    # inp -> portuguese, tar -> english
    for (batch, (tar, inp)) in enumerate(gen):
        train_step(inp, tar)

        if batch % 100 == 0:
            print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
                epoch + 1, batch, train_loss.result(), train_accuracy.result()))

    if (epoch + 1) % 5 == 0:
        ckpt_save_path = ckpt_manager.save()
        print ('Saving checkpoint for epoch {} at {}'.format(epoch+1,
                                                             ckpt_save_path))

    print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, 
                                                train_loss.result(), 
                                                train_accuracy.result()))

    print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 2.3096 Accuracy 0.0125
# Epoch 1 Batch 100 Loss 1.4638 Accuracy 0.1106
# Epoch 1 Batch 200 Loss 1.2606 Accuracy 0.1539
# Epoch 1 Batch 300 Loss 1.0910 Accuracy 0.1935
# Epoch 1 Batch 400 Loss 0.9699 Accuracy 0.2244
# Epoch 1 Batch 500 Loss 0.8794 Accuracy 0.2480
# Epoch 1 Batch 600 Loss 0.8089 Accuracy 0.2670
# Epoch 1 Batch 700 Loss 0.7517 Accuracy 0.2824
# Epoch 1 Batch 800 Loss 0.7046 Accuracy 0.2954
# Epoch 1 Batch 900 Loss 0.6650 Accuracy 0.3064
# Epoch 1 Batch 1000 Loss 0.6313 Accuracy 0.3159
# Epoch 1 Batch 1100 Loss 0.6017 Accuracy 0.3242
# Epoch 1 Loss 0.6017 Accuracy 0.3242
# Time taken for 1 epoch: 533.8319201469421 secs
#
# Epoch 2 Batch 0 Loss 0.3180 Accuracy 0.4036
# Epoch 2 Batch 100 Loss 0.2906 Accuracy 0.4144
# Epoch 2 Batch 200 Loss 0.2826 Accuracy 0.4163
# Epoch 2 Batch 300 Loss 0.2754 Accuracy 0.4188
# Epoch 2 Batch 400 Loss 0.2687 Accuracy 0.4211
# Epoch 2 Batch 500 Loss 0.2623 Accuracy 0.4235
# Epoch 2 Batch 600 Loss 0.2568 Accuracy 0.4254
# Epoch 2 Batch 700 Loss 0.2514 Accuracy 0.4272
# Epoch 2 Batch 800 Loss 0.2464 Accuracy 0.4290
# Epoch 2 Batch 900 Loss 0.2415 Accuracy 0.4308
# Epoch 2 Batch 1000 Loss 0.2368 Accuracy 0.4325
# Epoch 2 Batch 1100 Loss 0.2324 Accuracy 0.4340
# Epoch 2 Loss 0.2324 Accuracy 0.4340
# Time taken for 1 epoch: 527.2178614139557 secs
#
# Epoch 3 Batch 0 Loss 0.2577 Accuracy 0.4125
# Epoch 3 Batch 100 Loss 0.1954 Accuracy 0.4469
# Epoch 3 Batch 200 Loss 0.1844 Accuracy 0.4507
# Epoch 3 Batch 300 Loss 0.1787 Accuracy 0.4530
# Epoch 3 Batch 400 Loss 0.1747 Accuracy 0.4545
# Epoch 3 Batch 500 Loss 0.1711 Accuracy 0.4560
# Epoch 3 Batch 600 Loss 0.1678 Accuracy 0.4573
# Epoch 3 Batch 700 Loss 0.1658 Accuracy 0.4581
# Epoch 3 Batch 800 Loss 0.1630 Accuracy 0.4593
# Epoch 3 Batch 900 Loss 0.1605 Accuracy 0.4602
# Epoch 3 Batch 1000 Loss 0.1581 Accuracy 0.4611
# Epoch 3 Batch 1100 Loss 0.1555 Accuracy 0.4619
# Epoch 3 Loss 0.1555 Accuracy 0.4619
# Time taken for 1 epoch: 526.811802148819 secs
#
# Epoch 4 Batch 0 Loss 0.1802 Accuracy 0.4450
# Epoch 4 Batch 100 Loss 0.1289 Accuracy 0.4715
# Epoch 4 Batch 200 Loss 0.1261 Accuracy 0.4726
# Epoch 4 Batch 300 Loss 0.1237 Accuracy 0.4734
# Epoch 4 Batch 400 Loss 0.1220 Accuracy 0.4740
# Epoch 4 Batch 500 Loss 0.1206 Accuracy 0.4745
# Epoch 4 Batch 600 Loss 0.1183 Accuracy 0.4754
# Epoch 4 Batch 700 Loss 0.1170 Accuracy 0.4759
# Epoch 4 Batch 800 Loss 0.1153 Accuracy 0.4767
# Epoch 4 Batch 900 Loss 0.1135 Accuracy 0.4775
# Epoch 4 Batch 1000 Loss 0.1119 Accuracy 0.4780
# Epoch 4 Batch 1100 Loss 0.1100 Accuracy 0.4788
# Epoch 4 Loss 0.1100 Accuracy 0.4788
# Time taken for 1 epoch: 526.6245009899139 secs
#
# Epoch 5 Batch 0 Loss 0.1196 Accuracy 0.4774
# Epoch 5 Batch 100 Loss 0.0880 Accuracy 0.4865
# Epoch 5 Batch 200 Loss 0.0846 Accuracy 0.4881
# Epoch 5 Batch 300 Loss 0.0823 Accuracy 0.4886
# Epoch 5 Batch 400 Loss 0.0807 Accuracy 0.4895
# Epoch 5 Batch 500 Loss 0.0792 Accuracy 0.4901
# Epoch 5 Batch 600 Loss 0.0776 Accuracy 0.4909
# Epoch 5 Batch 700 Loss 0.0762 Accuracy 0.4914
# Epoch 5 Batch 800 Loss 0.0754 Accuracy 0.4917
# Epoch 5 Batch 900 Loss 0.0740 Accuracy 0.4922
# Epoch 5 Batch 1000 Loss 0.0725 Accuracy 0.4928
# Epoch 5 Batch 1100 Loss 0.0713 Accuracy 0.4932
# Saving checkpoint for epoch 5 at ./checkpoints/FPsToSMILES(DupliCount)/train\ckpt-1
# Epoch 5 Loss 0.0713 Accuracy 0.4932
# Time taken for 1 epoch: 528.9672689437866 secs
#
# Epoch 6 Batch 0 Loss 0.0622 Accuracy 0.5006
# Epoch 6 Batch 100 Loss 0.0573 Accuracy 0.4984
# Epoch 6 Batch 200 Loss 0.0542 Accuracy 0.4991
# Epoch 6 Batch 300 Loss 0.0525 Accuracy 0.4998
# Epoch 6 Batch 400 Loss 0.0517 Accuracy 0.5001
# Epoch 6 Batch 500 Loss 0.0510 Accuracy 0.5002
# Epoch 6 Batch 600 Loss 0.0503 Accuracy 0.5005
# Epoch 6 Batch 700 Loss 0.0496 Accuracy 0.5010
# Epoch 6 Batch 800 Loss 0.0489 Accuracy 0.5013
# Epoch 6 Batch 900 Loss 0.0481 Accuracy 0.5017
# Epoch 6 Batch 1000 Loss 0.0475 Accuracy 0.5020
# Epoch 6 Batch 1100 Loss 0.0469 Accuracy 0.5022
# Epoch 6 Loss 0.0469 Accuracy 0.5022
# Time taken for 1 epoch: 526.2110297679901 secs
#
# Epoch 7 Batch 0 Loss 0.0438 Accuracy 0.4887
# Epoch 7 Batch 100 Loss 0.0390 Accuracy 0.5063
# Epoch 7 Batch 200 Loss 0.0376 Accuracy 0.5060
# Epoch 7 Batch 300 Loss 0.0368 Accuracy 0.5059
# Epoch 7 Batch 400 Loss 0.0362 Accuracy 0.5062
# Epoch 7 Batch 500 Loss 0.0359 Accuracy 0.5062
# Epoch 7 Batch 600 Loss 0.0354 Accuracy 0.5063
# Epoch 7 Batch 700 Loss 0.0350 Accuracy 0.5066
# Epoch 7 Batch 800 Loss 0.0347 Accuracy 0.5068
# Epoch 7 Batch 900 Loss 0.0343 Accuracy 0.5068
# Epoch 7 Batch 1000 Loss 0.0340 Accuracy 0.5071
# Epoch 7 Batch 1100 Loss 0.0337 Accuracy 0.5072
# Epoch 7 Loss 0.0337 Accuracy 0.5072
# Time taken for 1 epoch: 526.0646109580994 secs
#
# Epoch 8 Batch 0 Loss 0.0289 Accuracy 0.5042
# Epoch 8 Batch 100 Loss 0.0275 Accuracy 0.5093
# Epoch 8 Batch 200 Loss 0.0269 Accuracy 0.5098
# Epoch 8 Batch 300 Loss 0.0268 Accuracy 0.5095
# Epoch 8 Batch 400 Loss 0.0267 Accuracy 0.5097
# Epoch 8 Batch 500 Loss 0.0266 Accuracy 0.5098
# Epoch 8 Batch 600 Loss 0.0264 Accuracy 0.5099
# Epoch 8 Batch 700 Loss 0.0263 Accuracy 0.5098
# Epoch 8 Batch 800 Loss 0.0262 Accuracy 0.5099
# Epoch 8 Batch 900 Loss 0.0259 Accuracy 0.5100
# Epoch 8 Batch 1000 Loss 0.0257 Accuracy 0.5101
# Epoch 8 Batch 1100 Loss 0.0256 Accuracy 0.5102
# Epoch 8 Loss 0.0256 Accuracy 0.5102
# Time taken for 1 epoch: 527.414088010788 secs
#
# Epoch 9 Batch 0 Loss 0.0226 Accuracy 0.5158
# Epoch 9 Batch 100 Loss 0.0211 Accuracy 0.5109
# Epoch 9 Batch 200 Loss 0.0210 Accuracy 0.5114
# Epoch 9 Batch 300 Loss 0.0212 Accuracy 0.5116
# Epoch 9 Batch 400 Loss 0.0212 Accuracy 0.5115
# Epoch 9 Batch 500 Loss 0.0212 Accuracy 0.5117
# Epoch 9 Batch 600 Loss 0.0212 Accuracy 0.5118
# Epoch 9 Batch 700 Loss 0.0210 Accuracy 0.5118
# Epoch 9 Batch 800 Loss 0.0209 Accuracy 0.5120
# Epoch 9 Batch 900 Loss 0.0209 Accuracy 0.5120
# Epoch 9 Batch 1000 Loss 0.0208 Accuracy 0.5119
# Epoch 9 Batch 1100 Loss 0.0206 Accuracy 0.5119
# Epoch 9 Loss 0.0206 Accuracy 0.5119
# Time taken for 1 epoch: 526.936466217041 secs
#
# Epoch 10 Batch 0 Loss 0.0190 Accuracy 0.5215
# Epoch 10 Batch 100 Loss 0.0175 Accuracy 0.5128
# Epoch 10 Batch 200 Loss 0.0174 Accuracy 0.5127
# Epoch 10 Batch 300 Loss 0.0174 Accuracy 0.5126
# Epoch 10 Batch 400 Loss 0.0174 Accuracy 0.5127
# Epoch 10 Batch 500 Loss 0.0175 Accuracy 0.5132
# Epoch 10 Batch 600 Loss 0.0174 Accuracy 0.5131
# Epoch 10 Batch 700 Loss 0.0174 Accuracy 0.5130
# Epoch 10 Batch 800 Loss 0.0173 Accuracy 0.5132
# Epoch 10 Batch 900 Loss 0.0173 Accuracy 0.5132
# Epoch 10 Batch 1000 Loss 0.0173 Accuracy 0.5132
# Epoch 10 Batch 1100 Loss 0.0172 Accuracy 0.5131
# Saving checkpoint for epoch 10 at ./checkpoints/FPsToSMILES(DupliCount)/train\ckpt-2
# Epoch 10 Loss 0.0172 Accuracy 0.5131
# Time taken for 1 epoch: 529.2467384338379 secs
#
# Epoch 11 Batch 0 Loss 0.0143 Accuracy 0.5039
# Epoch 11 Batch 100 Loss 0.0152 Accuracy 0.5147
# Epoch 11 Batch 200 Loss 0.0150 Accuracy 0.5145
# Epoch 11 Batch 300 Loss 0.0149 Accuracy 0.5142
# Epoch 11 Batch 400 Loss 0.0149 Accuracy 0.5142
# Epoch 11 Batch 500 Loss 0.0149 Accuracy 0.5141
# Epoch 11 Batch 600 Loss 0.0149 Accuracy 0.5140
# Epoch 11 Batch 700 Loss 0.0149 Accuracy 0.5142
# Epoch 11 Batch 800 Loss 0.0149 Accuracy 0.5140
# Epoch 11 Batch 900 Loss 0.0148 Accuracy 0.5139
# Epoch 11 Batch 1000 Loss 0.0148 Accuracy 0.5140
# Epoch 11 Batch 1100 Loss 0.0148 Accuracy 0.5140
# Epoch 11 Loss 0.0148 Accuracy 0.5140
# Time taken for 1 epoch: 528.4002184867859 secs
#
# Epoch 12 Batch 0 Loss 0.0113 Accuracy 0.5115
# Epoch 12 Batch 100 Loss 0.0133 Accuracy 0.5152
# Epoch 12 Batch 200 Loss 0.0131 Accuracy 0.5146
# Epoch 12 Batch 300 Loss 0.0129 Accuracy 0.5146
# Epoch 12 Batch 400 Loss 0.0128 Accuracy 0.5147
# Epoch 12 Batch 500 Loss 0.0129 Accuracy 0.5149
# Epoch 12 Batch 600 Loss 0.0129 Accuracy 0.5147
# Epoch 12 Batch 700 Loss 0.0129 Accuracy 0.5148
# Epoch 12 Batch 800 Loss 0.0128 Accuracy 0.5147
# Epoch 12 Batch 900 Loss 0.0128 Accuracy 0.5146
# Epoch 12 Batch 1000 Loss 0.0128 Accuracy 0.5147
# Epoch 12 Batch 1100 Loss 0.0128 Accuracy 0.5147
# Epoch 12 Loss 0.0128 Accuracy 0.5147
# Time taken for 1 epoch: 528.411634683609 secs
#
# Epoch 13 Batch 0 Loss 0.0092 Accuracy 0.5125
# Epoch 13 Batch 100 Loss 0.0106 Accuracy 0.5144
# Epoch 13 Batch 200 Loss 0.0110 Accuracy 0.5145
# Epoch 13 Batch 300 Loss 0.0111 Accuracy 0.5146
# Epoch 13 Batch 400 Loss 0.0112 Accuracy 0.5149
# Epoch 13 Batch 500 Loss 0.0112 Accuracy 0.5149
# Epoch 13 Batch 600 Loss 0.0113 Accuracy 0.5151
# Epoch 13 Batch 700 Loss 0.0113 Accuracy 0.5152
# Epoch 13 Batch 800 Loss 0.0113 Accuracy 0.5152
# Epoch 13 Batch 900 Loss 0.0113 Accuracy 0.5152
# Epoch 13 Batch 1000 Loss 0.0114 Accuracy 0.5152
# Epoch 13 Batch 1100 Loss 0.0113 Accuracy 0.5152
# Epoch 13 Loss 0.0113 Accuracy 0.5152
# Time taken for 1 epoch: 528.7615106105804 secs
#
# Epoch 14 Batch 0 Loss 0.0092 Accuracy 0.5265
# Epoch 14 Batch 100 Loss 0.0105 Accuracy 0.5163
# Epoch 14 Batch 200 Loss 0.0101 Accuracy 0.5159
# Epoch 14 Batch 300 Loss 0.0100 Accuracy 0.5155
# Epoch 14 Batch 400 Loss 0.0100 Accuracy 0.5155
# Epoch 14 Batch 500 Loss 0.0101 Accuracy 0.5155
# Epoch 14 Batch 600 Loss 0.0101 Accuracy 0.5156
# Epoch 14 Batch 700 Loss 0.0101 Accuracy 0.5157
# Epoch 14 Batch 800 Loss 0.0101 Accuracy 0.5157
# Epoch 14 Batch 900 Loss 0.0101 Accuracy 0.5156
# Epoch 14 Batch 1000 Loss 0.0101 Accuracy 0.5156
# Epoch 14 Batch 1100 Loss 0.0101 Accuracy 0.5156
# Epoch 14 Loss 0.0101 Accuracy 0.5156
# Time taken for 1 epoch: 528.1528744697571 secs
#
# Epoch 15 Batch 0 Loss 0.0123 Accuracy 0.5231
# Epoch 15 Batch 100 Loss 0.0093 Accuracy 0.5157
# Epoch 15 Batch 200 Loss 0.0091 Accuracy 0.5165
# Epoch 15 Batch 300 Loss 0.0091 Accuracy 0.5163
# Epoch 15 Batch 400 Loss 0.0091 Accuracy 0.5166
# Epoch 15 Batch 500 Loss 0.0091 Accuracy 0.5165
# Epoch 15 Batch 600 Loss 0.0091 Accuracy 0.5163
# Epoch 15 Batch 700 Loss 0.0091 Accuracy 0.5162
# Epoch 15 Batch 800 Loss 0.0091 Accuracy 0.5162
# Epoch 15 Batch 900 Loss 0.0092 Accuracy 0.5160
# Epoch 15 Batch 1000 Loss 0.0092 Accuracy 0.5160
# Epoch 15 Batch 1100 Loss 0.0091 Accuracy 0.5159
# Saving checkpoint for epoch 15 at ./checkpoints/FPsToSMILES(DupliCount)/train\ckpt-3
# Epoch 15 Loss 0.0091 Accuracy 0.5159
# Time taken for 1 epoch: 527.3454592227936 secs
#
# Epoch 16 Batch 0 Loss 0.0091 Accuracy 0.5049
# Epoch 16 Batch 100 Loss 0.0081 Accuracy 0.5179
# Epoch 16 Batch 200 Loss 0.0081 Accuracy 0.5171
# Epoch 16 Batch 300 Loss 0.0082 Accuracy 0.5167
# Epoch 16 Batch 400 Loss 0.0082 Accuracy 0.5168
# Epoch 16 Batch 500 Loss 0.0081 Accuracy 0.5167
# Epoch 16 Batch 600 Loss 0.0082 Accuracy 0.5167
# Epoch 16 Batch 700 Loss 0.0082 Accuracy 0.5166
# Epoch 16 Batch 800 Loss 0.0082 Accuracy 0.5163
# Epoch 16 Batch 900 Loss 0.0082 Accuracy 0.5163
# Epoch 16 Batch 1000 Loss 0.0083 Accuracy 0.5162
# Epoch 16 Batch 1100 Loss 0.0083 Accuracy 0.5162
# Epoch 16 Loss 0.0083 Accuracy 0.5162
# Time taken for 1 epoch: 527.4842414855957 secs
#
# Epoch 17 Batch 0 Loss 0.0070 Accuracy 0.5157
# Epoch 17 Batch 100 Loss 0.0072 Accuracy 0.5174
# Epoch 17 Batch 200 Loss 0.0072 Accuracy 0.5167
# Epoch 17 Batch 300 Loss 0.0073 Accuracy 0.5163
# Epoch 17 Batch 400 Loss 0.0074 Accuracy 0.5164
# Epoch 17 Batch 500 Loss 0.0074 Accuracy 0.5164
# Epoch 17 Batch 600 Loss 0.0074 Accuracy 0.5165
# Epoch 17 Batch 700 Loss 0.0075 Accuracy 0.5165
# Epoch 17 Batch 800 Loss 0.0075 Accuracy 0.5164
# Epoch 17 Batch 900 Loss 0.0075 Accuracy 0.5165
# Epoch 17 Batch 1000 Loss 0.0075 Accuracy 0.5166
# Epoch 17 Batch 1100 Loss 0.0075 Accuracy 0.5165
# Epoch 17 Loss 0.0075 Accuracy 0.5165
# Time taken for 1 epoch: 527.263875246048 secs
#
# Epoch 18 Batch 0 Loss 0.0080 Accuracy 0.5157
# Epoch 18 Batch 100 Loss 0.0066 Accuracy 0.5169
# Epoch 18 Batch 200 Loss 0.0067 Accuracy 0.5171
# Epoch 18 Batch 300 Loss 0.0067 Accuracy 0.5168
# Epoch 18 Batch 400 Loss 0.0068 Accuracy 0.5169
# Epoch 18 Batch 500 Loss 0.0068 Accuracy 0.5170
# Epoch 18 Batch 600 Loss 0.0068 Accuracy 0.5170
# Epoch 18 Batch 700 Loss 0.0069 Accuracy 0.5169
# Epoch 18 Batch 800 Loss 0.0069 Accuracy 0.5169
# Epoch 18 Batch 900 Loss 0.0069 Accuracy 0.5169
# Epoch 18 Batch 1000 Loss 0.0070 Accuracy 0.5168
# Epoch 18 Batch 1100 Loss 0.0070 Accuracy 0.5167
# Epoch 18 Loss 0.0070 Accuracy 0.5167
# Time taken for 1 epoch: 526.5305433273315 secs
#
# Epoch 19 Batch 0 Loss 0.0049 Accuracy 0.5284
# Epoch 19 Batch 100 Loss 0.0063 Accuracy 0.5160
# Epoch 19 Batch 200 Loss 0.0062 Accuracy 0.5166
# Epoch 19 Batch 300 Loss 0.0062 Accuracy 0.5171
# Epoch 19 Batch 400 Loss 0.0063 Accuracy 0.5173
# Epoch 19 Batch 500 Loss 0.0063 Accuracy 0.5173
# Epoch 19 Batch 600 Loss 0.0063 Accuracy 0.5171
# Epoch 19 Batch 700 Loss 0.0064 Accuracy 0.5172
# Epoch 19 Batch 800 Loss 0.0064 Accuracy 0.5171
# Epoch 19 Batch 900 Loss 0.0064 Accuracy 0.5170
# Epoch 19 Batch 1000 Loss 0.0064 Accuracy 0.5169
# Epoch 19 Batch 1100 Loss 0.0064 Accuracy 0.5169
# Epoch 19 Loss 0.0064 Accuracy 0.5169
# Time taken for 1 epoch: 526.608904838562 secs
#
# Epoch 20 Batch 0 Loss 0.0044 Accuracy 0.5132
# Epoch 20 Batch 100 Loss 0.0055 Accuracy 0.5177
# Epoch 20 Batch 200 Loss 0.0057 Accuracy 0.5171
# Epoch 20 Batch 300 Loss 0.0058 Accuracy 0.5173
# Epoch 20 Batch 400 Loss 0.0058 Accuracy 0.5173
# Epoch 20 Batch 500 Loss 0.0058 Accuracy 0.5172
# Epoch 20 Batch 600 Loss 0.0059 Accuracy 0.5171
# Epoch 20 Batch 700 Loss 0.0058 Accuracy 0.5173
# Epoch 20 Batch 800 Loss 0.0059 Accuracy 0.5172
# Epoch 20 Batch 900 Loss 0.0059 Accuracy 0.5171
# Epoch 20 Batch 1000 Loss 0.0060 Accuracy 0.5171
# Epoch 20 Batch 1100 Loss 0.0059 Accuracy 0.5171
# Saving checkpoint for epoch 20 at ./checkpoints/FPsToSMILES(DupliCount)/train\ckpt-4
# Epoch 20 Loss 0.0059 Accuracy 0.5171
# Time taken for 1 epoch: 527.702258348465 secs
#
# Epoch 21 Batch 0 Loss 0.0040 Accuracy 0.5189
# Epoch 21 Batch 100 Loss 0.0053 Accuracy 0.5184
# Epoch 21 Batch 200 Loss 0.0053 Accuracy 0.5180
# Epoch 21 Batch 300 Loss 0.0053 Accuracy 0.5180
# Epoch 21 Batch 400 Loss 0.0054 Accuracy 0.5179
# Epoch 21 Batch 500 Loss 0.0054 Accuracy 0.5175
# Epoch 21 Batch 600 Loss 0.0054 Accuracy 0.5174
# Epoch 21 Batch 700 Loss 0.0055 Accuracy 0.5173
# Epoch 21 Batch 800 Loss 0.0055 Accuracy 0.5174
# Epoch 21 Batch 900 Loss 0.0055 Accuracy 0.5174
# Epoch 21 Batch 1000 Loss 0.0055 Accuracy 0.5174
# Epoch 21 Batch 1100 Loss 0.0055 Accuracy 0.5172
# Epoch 21 Loss 0.0055 Accuracy 0.5172
# Time taken for 1 epoch: 526.4685158729553 secs
#
# Epoch 22 Batch 0 Loss 0.0035 Accuracy 0.5211
# Epoch 22 Batch 100 Loss 0.0050 Accuracy 0.5194
# Epoch 22 Batch 200 Loss 0.0050 Accuracy 0.5189
# Epoch 22 Batch 300 Loss 0.0050 Accuracy 0.5182
# Epoch 22 Batch 400 Loss 0.0051 Accuracy 0.5176
# Epoch 22 Batch 500 Loss 0.0051 Accuracy 0.5176
# Epoch 22 Batch 600 Loss 0.0052 Accuracy 0.5177
# Epoch 22 Batch 700 Loss 0.0051 Accuracy 0.5176
# Epoch 22 Batch 800 Loss 0.0052 Accuracy 0.5176
# Epoch 22 Batch 900 Loss 0.0052 Accuracy 0.5176
# Epoch 22 Batch 1000 Loss 0.0052 Accuracy 0.5175
# Epoch 22 Batch 1100 Loss 0.0052 Accuracy 0.5173
# Epoch 22 Loss 0.0052 Accuracy 0.5173
# Time taken for 1 epoch: 528.0257019996643 secs
#
# Epoch 23 Batch 0 Loss 0.0061 Accuracy 0.5087
# Epoch 23 Batch 100 Loss 0.0048 Accuracy 0.5167
# Epoch 23 Batch 200 Loss 0.0046 Accuracy 0.5174
# Epoch 23 Batch 300 Loss 0.0046 Accuracy 0.5174
# Epoch 23 Batch 400 Loss 0.0047 Accuracy 0.5174
# Epoch 23 Batch 500 Loss 0.0048 Accuracy 0.5176
# Epoch 23 Batch 600 Loss 0.0048 Accuracy 0.5177
# Epoch 23 Batch 700 Loss 0.0048 Accuracy 0.5178
# Epoch 23 Batch 800 Loss 0.0048 Accuracy 0.5175
# Epoch 23 Batch 900 Loss 0.0048 Accuracy 0.5176
# Epoch 23 Batch 1000 Loss 0.0048 Accuracy 0.5174
# Epoch 23 Batch 1100 Loss 0.0049 Accuracy 0.5174
# Epoch 23 Loss 0.0049 Accuracy 0.5174
# Time taken for 1 epoch: 528.1752872467041 secs
#
# Epoch 24 Batch 0 Loss 0.0063 Accuracy 0.5248
# Epoch 24 Batch 100 Loss 0.0042 Accuracy 0.5178
# Epoch 24 Batch 200 Loss 0.0043 Accuracy 0.5180
# Epoch 24 Batch 300 Loss 0.0043 Accuracy 0.5180
# Epoch 24 Batch 400 Loss 0.0044 Accuracy 0.5174
# Epoch 24 Batch 500 Loss 0.0044 Accuracy 0.5175
# Epoch 24 Batch 600 Loss 0.0044 Accuracy 0.5175
# Epoch 24 Batch 700 Loss 0.0044 Accuracy 0.5175
# Epoch 24 Batch 800 Loss 0.0045 Accuracy 0.5175
# Epoch 24 Batch 900 Loss 0.0045 Accuracy 0.5177
# Epoch 24 Batch 1000 Loss 0.0045 Accuracy 0.5176
# Epoch 24 Batch 1100 Loss 0.0045 Accuracy 0.5176
# Epoch 24 Loss 0.0045 Accuracy 0.5176
# Time taken for 1 epoch: 525.5812304019928 secs
#
# Epoch 25 Batch 0 Loss 0.0054 Accuracy 0.5079
# Epoch 25 Batch 100 Loss 0.0041 Accuracy 0.5173
# Epoch 25 Batch 200 Loss 0.0042 Accuracy 0.5173
# Epoch 25 Batch 300 Loss 0.0041 Accuracy 0.5172
# Epoch 25 Batch 400 Loss 0.0041 Accuracy 0.5172
# Epoch 25 Batch 500 Loss 0.0042 Accuracy 0.5172
# Epoch 25 Batch 600 Loss 0.0042 Accuracy 0.5174
# Epoch 25 Batch 700 Loss 0.0042 Accuracy 0.5176
# Epoch 25 Batch 800 Loss 0.0043 Accuracy 0.5175
# Epoch 25 Batch 900 Loss 0.0043 Accuracy 0.5175
# Epoch 25 Batch 1000 Loss 0.0043 Accuracy 0.5176
# Epoch 25 Batch 1100 Loss 0.0043 Accuracy 0.5176
# Saving checkpoint for epoch 25 at ./checkpoints/FPsToSMILES(DupliCount)/train\ckpt-5
# Epoch 25 Loss 0.0043 Accuracy 0.5176
# Time taken for 1 epoch: 528.8548016548157 secs
#
# Epoch 26 Batch 0 Loss 0.0039 Accuracy 0.4992
# Epoch 26 Batch 100 Loss 0.0038 Accuracy 0.5172
# Epoch 26 Batch 200 Loss 0.0039 Accuracy 0.5177
# Epoch 26 Batch 300 Loss 0.0039 Accuracy 0.5178
# Epoch 26 Batch 400 Loss 0.0039 Accuracy 0.5179
# Epoch 26 Batch 500 Loss 0.0039 Accuracy 0.5179
# Epoch 26 Batch 600 Loss 0.0040 Accuracy 0.5179
# Epoch 26 Batch 700 Loss 0.0040 Accuracy 0.5178
# Epoch 26 Batch 800 Loss 0.0040 Accuracy 0.5179
# Epoch 26 Batch 900 Loss 0.0040 Accuracy 0.5177
# Epoch 26 Batch 1000 Loss 0.0040 Accuracy 0.5178
# Epoch 26 Batch 1100 Loss 0.0040 Accuracy 0.5177
# Epoch 26 Loss 0.0040 Accuracy 0.5177
# Time taken for 1 epoch: 527.0642921924591 secs
#
# Epoch 27 Batch 0 Loss 0.0027 Accuracy 0.5270
# Epoch 27 Batch 100 Loss 0.0036 Accuracy 0.5185
# Epoch 27 Batch 200 Loss 0.0036 Accuracy 0.5183
# Epoch 27 Batch 300 Loss 0.0036 Accuracy 0.5180
# Epoch 27 Batch 400 Loss 0.0037 Accuracy 0.5179
# Epoch 27 Batch 500 Loss 0.0037 Accuracy 0.5180
# Epoch 27 Batch 600 Loss 0.0037 Accuracy 0.5178
# Epoch 27 Batch 700 Loss 0.0037 Accuracy 0.5179
# Epoch 27 Batch 800 Loss 0.0038 Accuracy 0.5179
# Epoch 27 Batch 900 Loss 0.0038 Accuracy 0.5179
# Epoch 27 Batch 1000 Loss 0.0038 Accuracy 0.5178
# Epoch 27 Batch 1100 Loss 0.0038 Accuracy 0.5178
# Epoch 27 Loss 0.0038 Accuracy 0.5178
# Time taken for 1 epoch: 528.1255753040314 secs
#
# Epoch 28 Batch 0 Loss 0.0046 Accuracy 0.5435
# Epoch 28 Batch 100 Loss 0.0034 Accuracy 0.5184
# Epoch 28 Batch 200 Loss 0.0035 Accuracy 0.5185
# Epoch 28 Batch 300 Loss 0.0035 Accuracy 0.5180
# Epoch 28 Batch 400 Loss 0.0035 Accuracy 0.5180
# Epoch 28 Batch 500 Loss 0.0035 Accuracy 0.5179
# Epoch 28 Batch 600 Loss 0.0036 Accuracy 0.5179
# Epoch 28 Batch 700 Loss 0.0036 Accuracy 0.5178
# Epoch 28 Batch 800 Loss 0.0036 Accuracy 0.5179
# Epoch 28 Batch 900 Loss 0.0036 Accuracy 0.5179
# Epoch 28 Batch 1000 Loss 0.0036 Accuracy 0.5178
# Epoch 28 Batch 1100 Loss 0.0036 Accuracy 0.5179
# Epoch 28 Loss 0.0036 Accuracy 0.5179
# Time taken for 1 epoch: 527.6930332183838 secs
#
# Epoch 29 Batch 0 Loss 0.0026 Accuracy 0.5031
# Epoch 29 Batch 100 Loss 0.0032 Accuracy 0.5184
# Epoch 29 Batch 200 Loss 0.0033 Accuracy 0.5182
# Epoch 29 Batch 300 Loss 0.0033 Accuracy 0.5183
# Epoch 29 Batch 400 Loss 0.0034 Accuracy 0.5183
# Epoch 29 Batch 500 Loss 0.0033 Accuracy 0.5182
# Epoch 29 Batch 600 Loss 0.0034 Accuracy 0.5181
# Epoch 29 Batch 700 Loss 0.0034 Accuracy 0.5182
# Epoch 29 Batch 800 Loss 0.0034 Accuracy 0.5180
# Epoch 29 Batch 900 Loss 0.0034 Accuracy 0.5180
# Epoch 29 Batch 1000 Loss 0.0034 Accuracy 0.5181
# Epoch 29 Batch 1100 Loss 0.0034 Accuracy 0.5179
# Epoch 29 Loss 0.0034 Accuracy 0.5179
# Time taken for 1 epoch: 528.0826485157013 secs
#
# Epoch 30 Batch 0 Loss 0.0049 Accuracy 0.5354
# Epoch 30 Batch 100 Loss 0.0031 Accuracy 0.5184
# Epoch 30 Batch 200 Loss 0.0031 Accuracy 0.5189
# Epoch 30 Batch 300 Loss 0.0031 Accuracy 0.5187
# Epoch 30 Batch 400 Loss 0.0031 Accuracy 0.5186
# Epoch 30 Batch 500 Loss 0.0032 Accuracy 0.5188
# Epoch 30 Batch 600 Loss 0.0031 Accuracy 0.5188
# Epoch 30 Batch 700 Loss 0.0032 Accuracy 0.5185
# Epoch 30 Batch 800 Loss 0.0032 Accuracy 0.5182
# Epoch 30 Batch 900 Loss 0.0032 Accuracy 0.5182
# Epoch 30 Batch 1000 Loss 0.0033 Accuracy 0.5181
# Epoch 30 Batch 1100 Loss 0.0033 Accuracy 0.5180
# Saving checkpoint for epoch 30 at ./checkpoints/FPsToSMILES(DupliCount)/train\ckpt-6
# Epoch 30 Loss 0.0033 Accuracy 0.5180
# Time taken for 1 epoch: 529.5874469280243 secs
#
# Epoch 31 Batch 0 Loss 0.0030 Accuracy 0.5179
# Epoch 31 Batch 100 Loss 0.0029 Accuracy 0.5171
# Epoch 31 Batch 200 Loss 0.0030 Accuracy 0.5172
# Epoch 31 Batch 300 Loss 0.0030 Accuracy 0.5175
# Epoch 31 Batch 400 Loss 0.0031 Accuracy 0.5176
# Epoch 31 Batch 500 Loss 0.0031 Accuracy 0.5179
# Epoch 31 Batch 600 Loss 0.0031 Accuracy 0.5179
# Epoch 31 Batch 700 Loss 0.0031 Accuracy 0.5181
# Epoch 31 Batch 800 Loss 0.0031 Accuracy 0.5180
# Epoch 31 Batch 900 Loss 0.0031 Accuracy 0.5181
# Epoch 31 Batch 1000 Loss 0.0031 Accuracy 0.5181
# Epoch 31 Batch 1100 Loss 0.0031 Accuracy 0.5180
# Epoch 31 Loss 0.0031 Accuracy 0.5180
# Time taken for 1 epoch: 528.9487969875336 secs
#
# Epoch 32 Batch 0 Loss 0.0033 Accuracy 0.5178
# Epoch 32 Batch 100 Loss 0.0027 Accuracy 0.5183
# Epoch 32 Batch 200 Loss 0.0027 Accuracy 0.5185
# Epoch 32 Batch 300 Loss 0.0028 Accuracy 0.5184
# Epoch 32 Batch 400 Loss 0.0028 Accuracy 0.5183
# Epoch 32 Batch 500 Loss 0.0028 Accuracy 0.5183
# Epoch 32 Batch 600 Loss 0.0029 Accuracy 0.5182
# Epoch 32 Batch 700 Loss 0.0029 Accuracy 0.5181
# Epoch 32 Batch 800 Loss 0.0029 Accuracy 0.5181
# Epoch 32 Batch 900 Loss 0.0030 Accuracy 0.5181
# Epoch 32 Batch 1000 Loss 0.0030 Accuracy 0.5182
# Epoch 32 Batch 1100 Loss 0.0030 Accuracy 0.5181
# Epoch 32 Loss 0.0030 Accuracy 0.5181
# Time taken for 1 epoch: 529.097784280777 secs
#
# Epoch 33 Batch 0 Loss 0.0012 Accuracy 0.5134
# Epoch 33 Batch 100 Loss 0.0026 Accuracy 0.5173
# Epoch 33 Batch 200 Loss 0.0026 Accuracy 0.5176
# Epoch 33 Batch 300 Loss 0.0026 Accuracy 0.5177
# Epoch 33 Batch 400 Loss 0.0027 Accuracy 0.5178
# Epoch 33 Batch 500 Loss 0.0027 Accuracy 0.5179
# Epoch 33 Batch 600 Loss 0.0027 Accuracy 0.5180
# Epoch 33 Batch 700 Loss 0.0028 Accuracy 0.5182
# Epoch 33 Batch 800 Loss 0.0028 Accuracy 0.5180
# Epoch 33 Batch 900 Loss 0.0028 Accuracy 0.5181
# Epoch 33 Batch 1000 Loss 0.0028 Accuracy 0.5181
# Epoch 33 Batch 1100 Loss 0.0028 Accuracy 0.5181
# Epoch 33 Loss 0.0028 Accuracy 0.5181
# Time taken for 1 epoch: 529.0518834590912 secs
#
# Epoch 34 Batch 0 Loss 0.0023 Accuracy 0.5130
# Epoch 34 Batch 100 Loss 0.0025 Accuracy 0.5186
# Epoch 34 Batch 200 Loss 0.0026 Accuracy 0.5184
# Epoch 34 Batch 300 Loss 0.0026 Accuracy 0.5180
# Epoch 34 Batch 400 Loss 0.0026 Accuracy 0.5182
# Epoch 34 Batch 500 Loss 0.0027 Accuracy 0.5181
# Epoch 34 Batch 600 Loss 0.0027 Accuracy 0.5181
# Epoch 34 Batch 700 Loss 0.0027 Accuracy 0.5181
# Epoch 34 Batch 800 Loss 0.0027 Accuracy 0.5181
# Epoch 34 Batch 900 Loss 0.0027 Accuracy 0.5182
# Epoch 34 Batch 1000 Loss 0.0027 Accuracy 0.5182
# Epoch 34 Batch 1100 Loss 0.0027 Accuracy 0.5182
# Epoch 34 Loss 0.0027 Accuracy 0.5182
# Time taken for 1 epoch: 527.7337510585785 secs
#
# Epoch 35 Batch 0 Loss 0.0024 Accuracy 0.5224
# Epoch 35 Batch 100 Loss 0.0024 Accuracy 0.5180
# Epoch 35 Batch 200 Loss 0.0026 Accuracy 0.5191
# Epoch 35 Batch 300 Loss 0.0026 Accuracy 0.5187
# Epoch 35 Batch 400 Loss 0.0025 Accuracy 0.5189
# Epoch 35 Batch 500 Loss 0.0026 Accuracy 0.5187
# Epoch 35 Batch 600 Loss 0.0026 Accuracy 0.5185
# Epoch 35 Batch 700 Loss 0.0026 Accuracy 0.5185
# Epoch 35 Batch 800 Loss 0.0026 Accuracy 0.5184
# Epoch 35 Batch 900 Loss 0.0026 Accuracy 0.5184
# Epoch 35 Batch 1000 Loss 0.0026 Accuracy 0.5183
# Epoch 35 Batch 1100 Loss 0.0026 Accuracy 0.5182
# Saving checkpoint for epoch 35 at ./checkpoints/FPsToSMILES(DupliCount)/train\ckpt-7
# Epoch 35 Loss 0.0026 Accuracy 0.5182
# Time taken for 1 epoch: 529.7216601371765 secs
