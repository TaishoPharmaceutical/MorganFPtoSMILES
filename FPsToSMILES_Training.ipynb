# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import random
import pickle
import time

from rdkit import Chem
from rdkit.Chem import Draw


fp_radius = 2
fp_bits = 2048

import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
from Transformer.Transformer import Transformer, create_look_ahead_mask, create_padding_mask, create_masks, CustomSchedule, evaluate, loss_function, BeamSearch 
from ChemUtils.PreProcessing import read_file, smiles_to_fp_array, CHAR_LEN, array_to_smiles

# %% [markdown]
# # Smiles and FP encoding

# %%
smiles_array, fp_array = read_file("Data/train.csv")

# %% [markdown]
# # Split train and test set

# %%
'''
train_rate = 0.98

r = np.random.uniform(size=[smiles_array.shape[0]])
r = r<0.98

train_smiles = smiles_array[r]
train_fp = fp_array[r]

test_smiles = smiles_array[~r]
test_fp = fp_array[~r]

with open("Data/train.pkl", "wb") as pf:
    pickle.dump([train_smiles,train_fp], pf)
    
with open("Data/test.pkl", "wb") as pf:
    pickle.dump([test_smiles,test_fp], pf)
'''
# Out:
# '\ntrain_rate = 0.98\n\nr = np.random.uniform(size=[smiles_array.shape[0]])\nr = r<0.98\n\ntrain_smiles = smiles_array[r]\ntrain_fp = fp_array[r]\n\ntest_smiles = smiles_array[~r]\ntest_fp = fp_array[~r]\n\nwith open("Data/train.pkl", "wb") as pf:\n    pickle.dump([train_smiles,train_fp], pf)\n    \nwith open("Data/test.pkl", "wb") as pf:\n    pickle.dump([test_smiles,test_fp], pf)\n'

# %% [markdown]
# # Define training data generator

# %%
#with open("Data/train.pkl",  'rb') as pf:
#    trains = pickle.load(pf)

BATCH_SIZE = 300

gen = tf.data.Dataset.from_tensor_slices((smiles_array,fp_array))
gen = gen.shuffle(buffer_size=smiles_array.shape[0])
gen = gen.batch(BATCH_SIZE)

AUTOTUNE = tf.data.experimental.AUTOTUNE
gen = gen.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Define transformer model

# %%
num_layers = 4
d_model = 256
num_heads = 8
dff = 2048
input_vocab_size=fp_bits+3
target_vocab_size = CHAR_LEN+3
pe_input = fp_array.shape[1]
pe_target= smiles_array.shape[1]
rate = 0.1
EPOCHS=35

transformer = Transformer(num_layers, d_model, num_heads, dff, 
                    input_vocab_size, target_vocab_size,
                    pe_input, pe_target, rate)

# %%
#transformer.load_weights("Models/FPsToSmiles")

# %% [markdown]
# # Metrics

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(
    name='train_accuracy')

# %% [markdown]
# # Training

# %%
learning_rate = CustomSchedule(d_model)
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                     epsilon=1e-9)

# %%
checkpoint_path = "./checkpoints/FPsToSMILES/train"

ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# restore
if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print ('Latest checkpoint restored!!')
# Out:
# Latest checkpoint restored!!

# %%
train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int32),
    tf.TensorSpec(shape=(None, None), dtype=tf.int32),
]

@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]
    enc_padding_mask, combined_mask, dec_padding_mask = create_masks(inp, tar_inp)

    with tf.GradientTape() as tape:
        predictions, _ = transformer(inp, tar_inp, 
                                     True, 
                                     enc_padding_mask, 
                                     combined_mask, 
                                     dec_padding_mask)
        loss = loss_function(tar_real, predictions)

    gradients = tape.gradient(loss, transformer.trainable_variables)    
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))

    train_loss(loss)
    train_accuracy(tar_real, predictions)

# %%
for epoch in range(EPOCHS):
    start = time.time()

    train_loss.reset_states()
    train_accuracy.reset_states()

    # inp -> portuguese, tar -> english
    for (batch, (tar, inp)) in enumerate(gen):
        train_step(inp, tar)

        if batch % 100 == 0:
            print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
                epoch + 1, batch, train_loss.result(), train_accuracy.result()))

    if (epoch + 1) % 5 == 0:
        ckpt_save_path = ckpt_manager.save()
        print ('Saving checkpoint for epoch {} at {}'.format(epoch+1,
                                                             ckpt_save_path))

    print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, 
                                                train_loss.result(), 
                                                train_accuracy.result()))

    print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 2.2029 Accuracy 0.0026
# Epoch 1 Batch 100 Loss 1.4521 Accuracy 0.1065
# Epoch 1 Batch 200 Loss 1.2109 Accuracy 0.1625
# Epoch 1 Batch 300 Loss 1.0516 Accuracy 0.2008
# Epoch 1 Batch 400 Loss 0.9387 Accuracy 0.2299
# Epoch 1 Batch 500 Loss 0.8533 Accuracy 0.2524
# Epoch 1 Batch 600 Loss 0.7867 Accuracy 0.2705
# Epoch 1 Batch 700 Loss 0.7326 Accuracy 0.2856
# Epoch 1 Loss 0.7167 Accuracy 0.2900
# Time taken for 1 epoch: 367.8356695175171 secs
#
# Epoch 2 Batch 0 Loss 0.3691 Accuracy 0.3856
# Epoch 2 Batch 100 Loss 0.3583 Accuracy 0.3919
# Epoch 2 Batch 200 Loss 0.3435 Accuracy 0.3966
# Epoch 2 Batch 300 Loss 0.3305 Accuracy 0.4009
# Epoch 2 Batch 400 Loss 0.3179 Accuracy 0.4050
# Epoch 2 Batch 500 Loss 0.3061 Accuracy 0.4091
# Epoch 2 Batch 600 Loss 0.2950 Accuracy 0.4131
# Epoch 2 Batch 700 Loss 0.2839 Accuracy 0.4170
# Epoch 2 Loss 0.2803 Accuracy 0.4182
# Time taken for 1 epoch: 360.5914988517761 secs
#
# Epoch 3 Batch 0 Loss 0.2022 Accuracy 0.4528
# Epoch 3 Batch 100 Loss 0.1921 Accuracy 0.4489
# Epoch 3 Batch 200 Loss 0.1833 Accuracy 0.4523
# Epoch 3 Batch 300 Loss 0.1760 Accuracy 0.4548
# Epoch 3 Batch 400 Loss 0.1691 Accuracy 0.4574
# Epoch 3 Batch 500 Loss 0.1625 Accuracy 0.4601
# Epoch 3 Batch 600 Loss 0.1570 Accuracy 0.4623
# Epoch 3 Batch 700 Loss 0.1516 Accuracy 0.4642
# Epoch 3 Loss 0.1498 Accuracy 0.4649
# Time taken for 1 epoch: 359.85640931129456 secs
#
# Epoch 4 Batch 0 Loss 0.1050 Accuracy 0.4748
# Epoch 4 Batch 100 Loss 0.1069 Accuracy 0.4798
# Epoch 4 Batch 200 Loss 0.1030 Accuracy 0.4816
# Epoch 4 Batch 300 Loss 0.1002 Accuracy 0.4830
# Epoch 4 Batch 400 Loss 0.0973 Accuracy 0.4842
# Epoch 4 Batch 500 Loss 0.0949 Accuracy 0.4853
# Epoch 4 Batch 600 Loss 0.0926 Accuracy 0.4863
# Epoch 4 Batch 700 Loss 0.0902 Accuracy 0.4871
# Epoch 4 Loss 0.0894 Accuracy 0.4874
# Time taken for 1 epoch: 360.48900175094604 secs
#
# Epoch 5 Batch 0 Loss 0.0756 Accuracy 0.4907
# Epoch 5 Batch 100 Loss 0.0698 Accuracy 0.4941
# Epoch 5 Batch 200 Loss 0.0679 Accuracy 0.4950
# Epoch 5 Batch 300 Loss 0.0666 Accuracy 0.4959
# Epoch 5 Batch 400 Loss 0.0654 Accuracy 0.4963
# Epoch 5 Batch 500 Loss 0.0645 Accuracy 0.4966
# Epoch 5 Batch 600 Loss 0.0635 Accuracy 0.4970
# Epoch 5 Batch 700 Loss 0.0622 Accuracy 0.4974
# Saving checkpoint for epoch 5 at ./checkpoints/FPsToSMILES/train/ckpt-1
# Epoch 5 Loss 0.0619 Accuracy 0.4975
# Time taken for 1 epoch: 371.2243676185608 secs
#
# Epoch 6 Batch 0 Loss 0.0626 Accuracy 0.4957
# Epoch 6 Batch 100 Loss 0.0505 Accuracy 0.5015
# Epoch 6 Batch 200 Loss 0.0503 Accuracy 0.5021
# Epoch 6 Batch 300 Loss 0.0500 Accuracy 0.5021
# Epoch 6 Batch 400 Loss 0.0494 Accuracy 0.5021
# Epoch 6 Batch 500 Loss 0.0489 Accuracy 0.5022
# Epoch 6 Batch 600 Loss 0.0480 Accuracy 0.5025
# Epoch 6 Batch 700 Loss 0.0476 Accuracy 0.5028
# Epoch 6 Loss 0.0473 Accuracy 0.5029
# Time taken for 1 epoch: 372.0635998249054 secs
#
# Epoch 7 Batch 0 Loss 0.0374 Accuracy 0.4981
# Epoch 7 Batch 100 Loss 0.0368 Accuracy 0.5060
# Epoch 7 Batch 200 Loss 0.0371 Accuracy 0.5063
# Epoch 7 Batch 300 Loss 0.0373 Accuracy 0.5064
# Epoch 7 Batch 400 Loss 0.0367 Accuracy 0.5066
# Epoch 7 Batch 500 Loss 0.0362 Accuracy 0.5069
# Epoch 7 Batch 600 Loss 0.0362 Accuracy 0.5070
# Epoch 7 Batch 700 Loss 0.0355 Accuracy 0.5071
# Epoch 7 Loss 0.0353 Accuracy 0.5071
# Time taken for 1 epoch: 372.4319589138031 secs
#
# Epoch 8 Batch 0 Loss 0.0274 Accuracy 0.5122
# Epoch 8 Batch 100 Loss 0.0288 Accuracy 0.5090
# Epoch 8 Batch 200 Loss 0.0292 Accuracy 0.5091
# Epoch 8 Batch 300 Loss 0.0288 Accuracy 0.5088
# Epoch 8 Batch 400 Loss 0.0286 Accuracy 0.5091
# Epoch 8 Batch 500 Loss 0.0286 Accuracy 0.5093
# Epoch 8 Batch 600 Loss 0.0283 Accuracy 0.5095
# Epoch 8 Batch 700 Loss 0.0282 Accuracy 0.5096
# Epoch 8 Loss 0.0280 Accuracy 0.5096
# Time taken for 1 epoch: 371.7350859642029 secs
#
# Epoch 9 Batch 0 Loss 0.0220 Accuracy 0.5101
# Epoch 9 Batch 100 Loss 0.0236 Accuracy 0.5124
# Epoch 9 Batch 200 Loss 0.0236 Accuracy 0.5108
# Epoch 9 Batch 300 Loss 0.0236 Accuracy 0.5110
# Epoch 9 Batch 400 Loss 0.0235 Accuracy 0.5113
# Epoch 9 Batch 500 Loss 0.0233 Accuracy 0.5112
# Epoch 9 Batch 600 Loss 0.0232 Accuracy 0.5112
# Epoch 9 Batch 700 Loss 0.0231 Accuracy 0.5113
# Epoch 9 Loss 0.0230 Accuracy 0.5113
# Time taken for 1 epoch: 371.7369861602783 secs
#
# Epoch 10 Batch 0 Loss 0.0193 Accuracy 0.5142
# Epoch 10 Batch 100 Loss 0.0197 Accuracy 0.5115
# Epoch 10 Batch 200 Loss 0.0198 Accuracy 0.5118
# Epoch 10 Batch 300 Loss 0.0198 Accuracy 0.5119
# Epoch 10 Batch 400 Loss 0.0198 Accuracy 0.5123
# Epoch 10 Batch 500 Loss 0.0197 Accuracy 0.5123
# Epoch 10 Batch 600 Loss 0.0198 Accuracy 0.5124
# Epoch 10 Batch 700 Loss 0.0197 Accuracy 0.5125
# Saving checkpoint for epoch 10 at ./checkpoints/FPsToSMILES/train/ckpt-2
# Epoch 10 Loss 0.0197 Accuracy 0.5125
# Time taken for 1 epoch: 371.7188951969147 secs
#
# Epoch 11 Batch 0 Loss 0.0181 Accuracy 0.5112
# Epoch 11 Batch 100 Loss 0.0167 Accuracy 0.5135
# Epoch 11 Batch 200 Loss 0.0169 Accuracy 0.5134
# Epoch 11 Batch 300 Loss 0.0171 Accuracy 0.5134
# Epoch 11 Batch 400 Loss 0.0171 Accuracy 0.5132
# Epoch 11 Batch 500 Loss 0.0172 Accuracy 0.5132
# Epoch 11 Batch 600 Loss 0.0171 Accuracy 0.5132
# Epoch 11 Batch 700 Loss 0.0171 Accuracy 0.5133
# Epoch 11 Loss 0.0171 Accuracy 0.5133
# Time taken for 1 epoch: 371.54042983055115 secs
#
# Epoch 12 Batch 0 Loss 0.0162 Accuracy 0.5100
# Epoch 12 Batch 100 Loss 0.0144 Accuracy 0.5144
# Epoch 12 Batch 200 Loss 0.0148 Accuracy 0.5137
# Epoch 12 Batch 300 Loss 0.0150 Accuracy 0.5138
# Epoch 12 Batch 400 Loss 0.0150 Accuracy 0.5140
# Epoch 12 Batch 500 Loss 0.0151 Accuracy 0.5139
# Epoch 12 Batch 600 Loss 0.0151 Accuracy 0.5139
# Epoch 12 Batch 700 Loss 0.0151 Accuracy 0.5140
# Epoch 12 Loss 0.0151 Accuracy 0.5140
# Time taken for 1 epoch: 371.15614318847656 secs
#
# Epoch 13 Batch 0 Loss 0.0122 Accuracy 0.5186
# Epoch 13 Batch 100 Loss 0.0133 Accuracy 0.5160
# Epoch 13 Batch 200 Loss 0.0133 Accuracy 0.5150
# Epoch 13 Batch 300 Loss 0.0133 Accuracy 0.5149
# Epoch 13 Batch 400 Loss 0.0134 Accuracy 0.5144
# Epoch 13 Batch 500 Loss 0.0134 Accuracy 0.5145
# Epoch 13 Batch 600 Loss 0.0134 Accuracy 0.5147
# Epoch 13 Batch 700 Loss 0.0134 Accuracy 0.5146
# Epoch 13 Loss 0.0134 Accuracy 0.5145
# Time taken for 1 epoch: 373.5475664138794 secs
#
# Epoch 14 Batch 0 Loss 0.0113 Accuracy 0.5154
# Epoch 14 Batch 100 Loss 0.0119 Accuracy 0.5148
# Epoch 14 Batch 200 Loss 0.0120 Accuracy 0.5149
# Epoch 14 Batch 300 Loss 0.0121 Accuracy 0.5147
# Epoch 14 Batch 400 Loss 0.0121 Accuracy 0.5147
# Epoch 14 Batch 500 Loss 0.0121 Accuracy 0.5148
# Epoch 14 Batch 600 Loss 0.0121 Accuracy 0.5149
# Epoch 14 Batch 700 Loss 0.0122 Accuracy 0.5150
# Epoch 14 Loss 0.0122 Accuracy 0.5150
# Time taken for 1 epoch: 372.76901388168335 secs
#
# Epoch 15 Batch 0 Loss 0.0116 Accuracy 0.5116
# Epoch 15 Batch 100 Loss 0.0107 Accuracy 0.5161
# Epoch 15 Batch 200 Loss 0.0108 Accuracy 0.5163
# Epoch 15 Batch 300 Loss 0.0108 Accuracy 0.5157
# Epoch 15 Batch 400 Loss 0.0109 Accuracy 0.5154
# Epoch 15 Batch 500 Loss 0.0109 Accuracy 0.5153
# Epoch 15 Batch 600 Loss 0.0109 Accuracy 0.5153
# Epoch 15 Batch 700 Loss 0.0110 Accuracy 0.5153
# Saving checkpoint for epoch 15 at ./checkpoints/FPsToSMILES/train/ckpt-3
# Epoch 15 Loss 0.0110 Accuracy 0.5153
# Time taken for 1 epoch: 371.79709243774414 secs
#
# Epoch 16 Batch 0 Loss 0.0074 Accuracy 0.5212
# Epoch 16 Batch 100 Loss 0.0096 Accuracy 0.5169
# Epoch 16 Batch 200 Loss 0.0098 Accuracy 0.5157
# Epoch 16 Batch 300 Loss 0.0098 Accuracy 0.5155
# Epoch 16 Batch 400 Loss 0.0099 Accuracy 0.5155
# Epoch 16 Batch 500 Loss 0.0100 Accuracy 0.5156
# Epoch 16 Batch 600 Loss 0.0101 Accuracy 0.5157
# Epoch 16 Batch 700 Loss 0.0101 Accuracy 0.5156
# Epoch 16 Loss 0.0101 Accuracy 0.5156
# Time taken for 1 epoch: 372.8539385795593 secs
#
# Epoch 17 Batch 0 Loss 0.0075 Accuracy 0.5149
# Epoch 17 Batch 100 Loss 0.0088 Accuracy 0.5163
# Epoch 17 Batch 200 Loss 0.0090 Accuracy 0.5159
# Epoch 17 Batch 300 Loss 0.0090 Accuracy 0.5161
# Epoch 17 Batch 400 Loss 0.0092 Accuracy 0.5161
# Epoch 17 Batch 500 Loss 0.0092 Accuracy 0.5161
# Epoch 17 Batch 600 Loss 0.0092 Accuracy 0.5160
# Epoch 17 Batch 700 Loss 0.0093 Accuracy 0.5159
# Epoch 17 Loss 0.0093 Accuracy 0.5159
# Time taken for 1 epoch: 372.29172682762146 secs
#
# Epoch 18 Batch 0 Loss 0.0064 Accuracy 0.5158
# Epoch 18 Batch 100 Loss 0.0081 Accuracy 0.5159
# Epoch 18 Batch 200 Loss 0.0081 Accuracy 0.5158
# Epoch 18 Batch 300 Loss 0.0082 Accuracy 0.5157
# Epoch 18 Batch 400 Loss 0.0083 Accuracy 0.5157
# Epoch 18 Batch 500 Loss 0.0084 Accuracy 0.5159
# Epoch 18 Batch 600 Loss 0.0085 Accuracy 0.5162
# Epoch 18 Batch 700 Loss 0.0086 Accuracy 0.5162
# Epoch 18 Loss 0.0086 Accuracy 0.5161
# Time taken for 1 epoch: 372.0579104423523 secs
#
# Epoch 19 Batch 0 Loss 0.0068 Accuracy 0.5226
# Epoch 19 Batch 100 Loss 0.0071 Accuracy 0.5163
# Epoch 19 Batch 200 Loss 0.0076 Accuracy 0.5162
# Epoch 19 Batch 300 Loss 0.0078 Accuracy 0.5162
# Epoch 19 Batch 400 Loss 0.0078 Accuracy 0.5165
# Epoch 19 Batch 500 Loss 0.0079 Accuracy 0.5166
# Epoch 19 Batch 600 Loss 0.0080 Accuracy 0.5165
# Epoch 19 Batch 700 Loss 0.0080 Accuracy 0.5164
# Epoch 19 Loss 0.0080 Accuracy 0.5164
# Time taken for 1 epoch: 371.724662065506 secs
#
# Epoch 20 Batch 0 Loss 0.0058 Accuracy 0.5178
# Epoch 20 Batch 100 Loss 0.0070 Accuracy 0.5163
# Epoch 20 Batch 200 Loss 0.0071 Accuracy 0.5168
# Epoch 20 Batch 300 Loss 0.0072 Accuracy 0.5165
# Epoch 20 Batch 400 Loss 0.0072 Accuracy 0.5167
# Epoch 20 Batch 500 Loss 0.0073 Accuracy 0.5167
# Epoch 20 Batch 600 Loss 0.0074 Accuracy 0.5167
# Epoch 20 Batch 700 Loss 0.0074 Accuracy 0.5166
# Saving checkpoint for epoch 20 at ./checkpoints/FPsToSMILES/train/ckpt-4
# Epoch 20 Loss 0.0074 Accuracy 0.5166
# Time taken for 1 epoch: 373.5470235347748 secs
#
# Epoch 21 Batch 0 Loss 0.0068 Accuracy 0.5105
# Epoch 21 Batch 100 Loss 0.0066 Accuracy 0.5165
# Epoch 21 Batch 200 Loss 0.0067 Accuracy 0.5173
# Epoch 21 Batch 300 Loss 0.0068 Accuracy 0.5170
# Epoch 21 Batch 400 Loss 0.0068 Accuracy 0.5170
# Epoch 21 Batch 500 Loss 0.0069 Accuracy 0.5169
# Epoch 21 Batch 600 Loss 0.0069 Accuracy 0.5168
# Epoch 21 Batch 700 Loss 0.0069 Accuracy 0.5167
# Epoch 21 Loss 0.0070 Accuracy 0.5167
# Time taken for 1 epoch: 372.26415824890137 secs
#
# Epoch 22 Batch 0 Loss 0.0059 Accuracy 0.5247
# Epoch 22 Batch 100 Loss 0.0059 Accuracy 0.5180
# Epoch 22 Batch 200 Loss 0.0060 Accuracy 0.5173
# Epoch 22 Batch 300 Loss 0.0062 Accuracy 0.5170
# Epoch 22 Batch 400 Loss 0.0063 Accuracy 0.5170
# Epoch 22 Batch 500 Loss 0.0064 Accuracy 0.5170
# Epoch 22 Batch 600 Loss 0.0064 Accuracy 0.5168
# Epoch 22 Batch 700 Loss 0.0065 Accuracy 0.5168
# Epoch 22 Loss 0.0065 Accuracy 0.5168
# Time taken for 1 epoch: 372.04923605918884 secs
#
# Epoch 23 Batch 0 Loss 0.0057 Accuracy 0.5136
# Epoch 23 Batch 100 Loss 0.0057 Accuracy 0.5177
# Epoch 23 Batch 200 Loss 0.0058 Accuracy 0.5179
# Epoch 23 Batch 300 Loss 0.0059 Accuracy 0.5173
# Epoch 23 Batch 400 Loss 0.0059 Accuracy 0.5173
# Epoch 23 Batch 500 Loss 0.0060 Accuracy 0.5171
# Epoch 23 Batch 600 Loss 0.0060 Accuracy 0.5172
# Epoch 23 Batch 700 Loss 0.0061 Accuracy 0.5171
# Epoch 23 Loss 0.0061 Accuracy 0.5170
# Time taken for 1 epoch: 372.45638942718506 secs
#
# Epoch 24 Batch 0 Loss 0.0046 Accuracy 0.5186
# Epoch 24 Batch 100 Loss 0.0056 Accuracy 0.5182
# Epoch 24 Batch 200 Loss 0.0056 Accuracy 0.5177
# Epoch 24 Batch 300 Loss 0.0056 Accuracy 0.5175
# Epoch 24 Batch 400 Loss 0.0057 Accuracy 0.5176
# Epoch 24 Batch 500 Loss 0.0057 Accuracy 0.5174
# Epoch 24 Batch 600 Loss 0.0058 Accuracy 0.5173
# Epoch 24 Batch 700 Loss 0.0058 Accuracy 0.5171
# Epoch 24 Loss 0.0058 Accuracy 0.5171
# Time taken for 1 epoch: 373.2782859802246 secs
#
# Epoch 25 Batch 0 Loss 0.0037 Accuracy 0.5203
# Epoch 25 Batch 100 Loss 0.0048 Accuracy 0.5164
# Epoch 25 Batch 200 Loss 0.0051 Accuracy 0.5167
# Epoch 25 Batch 300 Loss 0.0052 Accuracy 0.5168
# Epoch 25 Batch 400 Loss 0.0053 Accuracy 0.5171
# Epoch 25 Batch 500 Loss 0.0054 Accuracy 0.5172
# Epoch 25 Batch 600 Loss 0.0054 Accuracy 0.5171
# Epoch 25 Batch 700 Loss 0.0055 Accuracy 0.5173
# Saving checkpoint for epoch 25 at ./checkpoints/FPsToSMILES/train/ckpt-5
# Epoch 25 Loss 0.0055 Accuracy 0.5172
# Time taken for 1 epoch: 372.0690829753876 secs
#
# Epoch 26 Batch 0 Loss 0.0050 Accuracy 0.5257
# Epoch 26 Batch 100 Loss 0.0049 Accuracy 0.5176
# Epoch 26 Batch 200 Loss 0.0050 Accuracy 0.5175
# Epoch 26 Batch 300 Loss 0.0050 Accuracy 0.5177
# Epoch 26 Batch 400 Loss 0.0051 Accuracy 0.5176
# Epoch 26 Batch 500 Loss 0.0051 Accuracy 0.5174
# Epoch 26 Batch 600 Loss 0.0051 Accuracy 0.5173
# Epoch 26 Batch 700 Loss 0.0052 Accuracy 0.5172
# Epoch 26 Loss 0.0052 Accuracy 0.5173
# Time taken for 1 epoch: 373.45659852027893 secs
#
# Epoch 27 Batch 0 Loss 0.0061 Accuracy 0.5199
# Epoch 27 Batch 100 Loss 0.0048 Accuracy 0.5175
# Epoch 27 Batch 200 Loss 0.0048 Accuracy 0.5177
# Epoch 27 Batch 300 Loss 0.0048 Accuracy 0.5173
# Epoch 27 Batch 400 Loss 0.0049 Accuracy 0.5172
# Epoch 27 Batch 500 Loss 0.0049 Accuracy 0.5174
# Epoch 27 Batch 600 Loss 0.0049 Accuracy 0.5174
# Epoch 27 Batch 700 Loss 0.0049 Accuracy 0.5174
# Epoch 27 Loss 0.0050 Accuracy 0.5174
# Time taken for 1 epoch: 372.55453753471375 secs
#
# Epoch 28 Batch 0 Loss 0.0032 Accuracy 0.5167
# Epoch 28 Batch 100 Loss 0.0043 Accuracy 0.5182
# Epoch 28 Batch 200 Loss 0.0044 Accuracy 0.5178
# Epoch 28 Batch 300 Loss 0.0045 Accuracy 0.5177
# Epoch 28 Batch 400 Loss 0.0046 Accuracy 0.5178
# Epoch 28 Batch 500 Loss 0.0046 Accuracy 0.5177
# Epoch 28 Batch 600 Loss 0.0047 Accuracy 0.5176
# Epoch 28 Batch 700 Loss 0.0047 Accuracy 0.5175
# Epoch 28 Loss 0.0047 Accuracy 0.5175
# Time taken for 1 epoch: 372.22692251205444 secs
#
# Epoch 29 Batch 0 Loss 0.0031 Accuracy 0.5095
# Epoch 29 Batch 100 Loss 0.0041 Accuracy 0.5178
# Epoch 29 Batch 200 Loss 0.0042 Accuracy 0.5178
# Epoch 29 Batch 300 Loss 0.0043 Accuracy 0.5179
# Epoch 29 Batch 400 Loss 0.0044 Accuracy 0.5178
# Epoch 29 Batch 500 Loss 0.0044 Accuracy 0.5177
# Epoch 29 Batch 600 Loss 0.0044 Accuracy 0.5176
# Epoch 29 Batch 700 Loss 0.0045 Accuracy 0.5175
# Epoch 29 Loss 0.0045 Accuracy 0.5175
# Time taken for 1 epoch: 372.0397844314575 secs
#
# Epoch 30 Batch 0 Loss 0.0037 Accuracy 0.5164
# Epoch 30 Batch 100 Loss 0.0040 Accuracy 0.5182
# Epoch 30 Batch 200 Loss 0.0041 Accuracy 0.5181
# Epoch 30 Batch 300 Loss 0.0042 Accuracy 0.5180
# Epoch 30 Batch 400 Loss 0.0042 Accuracy 0.5179
# Epoch 30 Batch 500 Loss 0.0043 Accuracy 0.5179
# Epoch 30 Batch 600 Loss 0.0043 Accuracy 0.5178
# Epoch 30 Batch 700 Loss 0.0043 Accuracy 0.5176
# Saving checkpoint for epoch 30 at ./checkpoints/FPsToSMILES/train/ckpt-6
# Epoch 30 Loss 0.0043 Accuracy 0.5176
# Time taken for 1 epoch: 373.2816803455353 secs
#
# Epoch 31 Batch 0 Loss 0.0034 Accuracy 0.5223
# Epoch 31 Batch 100 Loss 0.0039 Accuracy 0.5178
# Epoch 31 Batch 200 Loss 0.0039 Accuracy 0.5175
# Epoch 31 Batch 300 Loss 0.0040 Accuracy 0.5175
# Epoch 31 Batch 400 Loss 0.0040 Accuracy 0.5174
# Epoch 31 Batch 500 Loss 0.0041 Accuracy 0.5176
# Epoch 31 Batch 600 Loss 0.0041 Accuracy 0.5176
# Epoch 31 Batch 700 Loss 0.0041 Accuracy 0.5176
# Epoch 31 Loss 0.0041 Accuracy 0.5177
# Time taken for 1 epoch: 372.55713987350464 secs
#
# Epoch 32 Batch 0 Loss 0.0035 Accuracy 0.5241
# Epoch 32 Batch 100 Loss 0.0037 Accuracy 0.5183
# Epoch 32 Batch 200 Loss 0.0037 Accuracy 0.5178
# Epoch 32 Batch 300 Loss 0.0038 Accuracy 0.5178
# Epoch 32 Batch 400 Loss 0.0038 Accuracy 0.5181
# Epoch 32 Batch 500 Loss 0.0039 Accuracy 0.5180
# Epoch 32 Batch 600 Loss 0.0039 Accuracy 0.5178
# Epoch 32 Batch 700 Loss 0.0039 Accuracy 0.5178
# Epoch 32 Loss 0.0039 Accuracy 0.5178
# Time taken for 1 epoch: 372.1746735572815 secs
#
# Epoch 33 Batch 0 Loss 0.0044 Accuracy 0.5109
# Epoch 33 Batch 100 Loss 0.0035 Accuracy 0.5188
# Epoch 33 Batch 200 Loss 0.0036 Accuracy 0.5182
# Epoch 33 Batch 300 Loss 0.0036 Accuracy 0.5178
# Epoch 33 Batch 400 Loss 0.0037 Accuracy 0.5177
# Epoch 33 Batch 500 Loss 0.0037 Accuracy 0.5176
# Epoch 33 Batch 600 Loss 0.0037 Accuracy 0.5177
# Epoch 33 Batch 700 Loss 0.0038 Accuracy 0.5178
# Epoch 33 Loss 0.0038 Accuracy 0.5178
# Time taken for 1 epoch: 371.60442781448364 secs
#
# Epoch 34 Batch 0 Loss 0.0024 Accuracy 0.5185
# Epoch 34 Batch 100 Loss 0.0034 Accuracy 0.5188
# Epoch 34 Batch 200 Loss 0.0034 Accuracy 0.5187
# Epoch 34 Batch 300 Loss 0.0035 Accuracy 0.5179
# Epoch 34 Batch 400 Loss 0.0035 Accuracy 0.5180
# Epoch 34 Batch 500 Loss 0.0036 Accuracy 0.5178
# Epoch 34 Batch 600 Loss 0.0036 Accuracy 0.5177
# Epoch 34 Batch 700 Loss 0.0036 Accuracy 0.5178
# Epoch 34 Loss 0.0036 Accuracy 0.5178
# Time taken for 1 epoch: 372.6732189655304 secs
#
# Epoch 35 Batch 0 Loss 0.0030 Accuracy 0.5138
# Epoch 35 Batch 100 Loss 0.0032 Accuracy 0.5173
# Epoch 35 Batch 200 Loss 0.0033 Accuracy 0.5177
# Epoch 35 Batch 300 Loss 0.0034 Accuracy 0.5180
# Epoch 35 Batch 400 Loss 0.0034 Accuracy 0.5177
# Epoch 35 Batch 500 Loss 0.0034 Accuracy 0.5177
# Epoch 35 Batch 600 Loss 0.0035 Accuracy 0.5178
# Epoch 35 Batch 700 Loss 0.0035 Accuracy 0.5179
# Saving checkpoint for epoch 35 at ./checkpoints/FPsToSMILES/train/ckpt-7
# Epoch 35 Loss 0.0035 Accuracy 0.5179
# Time taken for 1 epoch: 373.28779792785645 secs
